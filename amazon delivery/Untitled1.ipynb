# %%
import codecs
import json
import pandas as pd
pd.options.mode.chained_assignment = None
# this enables us for rewriting dataframe to previous variable
from typing import List, Dict

json_twitter_data = pd.read_json(open("30Arpil.json"))
json_twitter_data.head()
# Out:
#    has_media      hashtags img_urls  is_replied  is_reply_to  likes links  \
# 0      False            []       []        True         True      0    []
# 1      False            []       []        True        False      0    []
# 2      False  [deadspace3]       []       False        False      0    []
# 3      False            []       []       False        False      0    []
# 4      False            []       []       False         True      0    []
#
#       parent_tweet_id  replies  \
# 0  298559900987035651        1
# 1                            1
# 2                            0
# 3                            0
# 4  298555116204748801        0
#
#                                       reply_to_users  ...     screen_name  \
# 0  [{'screen_name': 'AndrewAshling', 'user_id': '...  ...      kiazishiru
# 1                                                 []  ...  krystle_mcCann
# 2                                                 []  ...     ChefSkeptic
# 3                                                 []  ...   Deuce_Devious
# 4  [{'screen_name': 'craiguk', 'user_id': '171763...  ...      danbayliss
#
#                                                 text  \
# 0  @AndrewAshling Amazon changed that rule about ...
# 1  I ordered a phone cover off amazon and its est...
# 2  I love buying games thru @amazon . no tax, rel...
# 3  Amazon Student is too savage.... Free 2day shi...
# 4  @craiguk I should of bulk purchased some tins ...
#
#                                            text_html           timestamp  \
# 0  <p class="TweetTextSize js-tweet-text tweet-te... 2013-02-04 23:05:01
# 1  <p class="TweetTextSize js-tweet-text tweet-te... 2013-02-04 22:44:29
# 2  <p class="TweetTextSize js-tweet-text tweet-te... 2013-02-04 22:40:39
# 3  <p class="TweetTextSize js-tweet-text tweet-te... 2013-02-04 22:33:35
# 4  <p class="TweetTextSize js-tweet-text tweet-te... 2013-02-04 22:23:29
#
#      timestamp_epochs            tweet_id  \
# 0 2013-02-04 23:05:01  298567866591113216
# 1 2013-02-04 22:44:29  298562700722708480
# 2 2013-02-04 22:40:39  298561737106526208
# 3 2013-02-04 22:33:35  298559959497596928
# 4 2013-02-04 22:23:29  298557413831880704
#
#                                    tweet_url    user_id        username  \
# 0      /kiazishiru/status/298567866591113216  263374903    Kia Zi Shiru
# 1  /krystle_mcCann/status/298562700722708480   42453316       𝙺𝚛𝚢𝚜𝚝𝚕𝚎 ✨
# 2     /ChefSkeptic/status/298561737106526208   43892262          Jarrid
# 3   /Deuce_Devious/status/298559959497596931   40120678  Derrick DeWitt
# 4      /danbayliss/status/298557413831880704    1262981             Dan
#
#   video_url
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 21 columns]

# %%
json_twitter_data.drop(columns=['has_media', 'hashtags', 'img_urls', 'is_replied','is_reply_to','likes','links','parent_tweet_id','replies','reply_to_users','screen_name','text_html','timestamp','timestamp_epochs','user_id','tweet_url','video_url'], inplace=True)
json_twitter_data.head()
# Out:
#    retweets                                               text  \
# 0         0  @AndrewAshling Amazon changed that rule about ...
# 1         0  I ordered a phone cover off amazon and its est...
# 2         0  I love buying games thru @amazon . no tax, rel...
# 3         0  Amazon Student is too savage.... Free 2day shi...
# 4         0  @craiguk I should of bulk purchased some tins ...
#
#              tweet_id        username
# 0  298567866591113216    Kia Zi Shiru
# 1  298562700722708480       𝙺𝚛𝚢𝚜𝚝𝚕𝚎 ✨
# 2  298561737106526208          Jarrid
# 3  298559959497596928  Derrick DeWitt
# 4  298557413831880704             Dan

# %%
import json
import csv

# input data
# json_file = open("30Arpil.json", "r")
# json_data = json.load(json_file)
# json_file.close()

# data = json.loads(json_data)

data = pd.read_json(open("30Arpil.json"))

tsv_file = open("data.tsv", "w")
tsv_writer = csv.writer(tsv_file, delimiter='\t')

tsv_writer.writerow(data[0].keys()) # write the header

for row in data: # write data rows
    tsv_writer.writerow(row.values())

tsv_file.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-199946a5ab72> in <module>
#      14 tsv_writer = csv.writer(tsv_file, delimiter='\t')
#      15
# ---> 16 tsv_writer.writerow(data[0].keys()) # write the header
#      17
#      18 for row in data: # write data rows
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
